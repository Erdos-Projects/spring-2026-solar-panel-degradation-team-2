# %%
import json
import pandas as pd
from pathlib import Path, PurePath

# %%
p = PurePath('../../data/raw/csv-metadata/3_system_metadata.json')

# %%
p.parts[-1]
# Out:
# '3_system_metadata.json'

# %%
q = Path('../../data/raw/csv-metadata/3_system_metadata.json')
q.parts[-1]
# Out:
# '3_system_metadata.json'

# %%
    csv_metadata_dir = Path('../../data/raw/csv-metadata/')
    # now grab the json files, infer the system_id, and
    # check for metadata
    jsons = csv_metadata_dir.glob("*_system_metadata.json")
    allprint_string = ''
    for file_path in jsons:
        system_id = int(
            file_path.parts[-1].replace('_system_metadata.json', '')
        )
        allprint_string = allprint_string + str(system_id)
    allprint_string
# Out:
# '...'
