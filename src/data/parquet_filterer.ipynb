# %%
import pandas as pd
from pathlib import Path
import pyarrow as pa  # not yet needed, might need it later
import pyarrow.parquet as pq
import pyarrow.compute as pc  # not yet needed, might need it later.

# %% [markdown]
# ## Reading Parquet-systems metrics metadata
# First, look at the parquet metrics and see which ones you wish to study.

# %%
metrics_dir = Path('../../data/raw/parquet-metrics/')
# Note: We generally give a directory, rather than an individual file, to the next step.
metrics_pq = pq.ParquetDataset(metrics_dir)
metrics_df = metrics_pq.read().to_pandas()
metrics_df.columns
# Out:
# Index(['system_id', 'metric_id', 'sensor_name', 'common_name', 'raw_units',
#        'units', 'calc_scale', 'calc_offset', 'calc_details',
#        'aggregation_type', 'source_type', 'source_id', 'comments',
#        'standard_name'],
#       dtype='object')

# %%
metrics_df['sensor_name'].unique()
# Out:
# array(['dc_power', 'ac_power', 'ac_current', 'ac_voltage',
#        'dc_pos_current', 'das_battery_voltage', 'poa_irradiance',
#        'ambient_temp', 'module_temp_1', 'module_temp_2', 'module_temp_3',
#        'inverter_temp', 'dc_pos_voltage', 'das_temp', 'inv1_ac_power',
#        'inv1_dc_power', 'inv2_ac_power', 'inv2_dc_power', 'inv3_ac_power',
#        'inv3_dc_power', 'inv4_ac_power', 'inv4_dc_power', 'inv5_ac_power',
#        'inv5_dc_power', 'inv6_ac_power', 'inv6_dc_power', 'inv7_ac_power',
#        'inv7_dc_power', 'inv1_dc_current', 'inv2_dc_current',
#        'inv3_dc_current', 'inv4_dc_current', 'inv5_dc_current',
#        'inv6_dc_current', 'inv7_dc_current', 'inv1_temp', 'inv2_temp',
#        'inv3_temp', 'inv5_temp', 'inv6_temp', 'inv1_dc_voltage',
#        'inv2_dc_voltage', 'inv3_dc_voltage', 'inv4_dc_voltage',
#        'inv5_dc_voltage', 'inv6_dc_voltage', 'inv7_dc_voltage',
#        'inv4_dc_temp', 'inv7_temp', 'ac_power_metered_kW', 'ac_frequency',
#        'module_temp_F', 'ambient_temp_F', 'inv4_temp', 'power_factor',
#        'wind_speed_mph', 'dc_power_hW', 'ac_power_hW', 'dc_current',
#        'module_temp_K', 'ambient_temp_K', 'dc_voltage',
#        'inverter_error_code', 'wind_speed', 'inv1_ac_power_hW',
#        'inv1_dc_power_hW', 'inv2_ac_power_hW', 'inv2_dc_power_hW',
#        'ac_inverter_power', 'inv1_ac_current', 'inv2_ac_current',
#        'ac_meter_1_power_kW', 'ac_meter_2_power_kW', 'inv1_power_factor',
#        'inv2_power_factor', 'inv1_ac_voltage', 'inv2_ac_voltage',
#        'gh_irradiance', 'relative_humidity', 'inv1_error_code',
#        'inv2_error_code', 'inv8_ac_power', 'inv8_dc_power',
#        'inv9_ac_power', 'inv9_dc_power', 'inv8_dc_current',
#        'inv9_dc_current', 'module_temp', 'inv8_dc_voltage',
#        'inv9_dc_voltage', 'dc_power_A1', 'dc_power_A2', 'dc_power_B1',
#        'dc_power_B2', 'dc_power_C1', 'dc_power_C2',
#        'poa_irradiance_cs300_1', 'poa_irradiance_cs300_2',
#        'poa_irradiance_lp02_2', 'direct_normal_dr01', 'dc_voltage_A',
#        'dc_voltage_B', 'dc_voltage_C', 'ac_power_metered_1_2',
#        'inv1_ac_power_kW', 'inv2_ac_power_kW', 'A_avg', 'PPV_avg',
#        'W_avg', 'Wh_sum', 'Wh_n_sum', 'W_n_avg', 'module_temp_5',
#        'module_temp_6', 'module_temp_7', 'module_temp_8', 'module_temp_9',
#        'module_temp_10', 'module_temp_11', 'module_temp_12',
#        'module_temp_13', 'module_temp_4', 'poa_irradiance_south_array',
#        'poa_irradiance_west_array', 'module_temp_south_F',
#        'module_temp_west_F', 'ambient_temp_1_F', 'ambient_temp_2_F',
#        'total_energy_kWh', 'wind_direction', 'ac_power_kW', 'energy',
#        'input_voltage', 'input_current', 'inv1_input_voltage',
#        'inv2_input_voltage', 'inv1_input_current', 'inv2_input_current',
#        'POA_irradiance', 'POA_irradiance_refcell', 'refcell_temp',
#        'poa_irradiance_2', 'reference_cell_temperature', 'das_temp_2',
#        'IntSolIrrad', 'error', 'dc_power_calc', 'ac_current_1',
#        'dc_current_1', 'ac_power_1', 'dc_power_1_calc', 'ac_current_2',
#        'dc_current_2', 'ac_power_2', 'dc_power_2_calc', 'ac_current_3',
#        'dc_current_3', 'ac_power_3', 'dc_power_3_calc', 'ac_voltage_1',
#        'ac_voltage_2', 'ac_voltage_3', 'dc_voltage_1', 'dc_voltage_2',
#        'dc_voltage_3', 'dc_current_4', 'ac_power_4', 'dc_current_5',
#        'ac_power_5', 'dc_current_6', 'ac_power_6', 'dc_power_4_calc',
#        'dc_power_5_calc', 'dc_power_6_calc', 'ac_power_1_6',
#        'dc_power_1_6', 'ac_voltage_4', 'ac_voltage_5', 'ac_voltage_6',
#        'dc_voltage_4', 'dc_voltage_5', 'dc_voltage_6', 'VATotal', 'RTW',
#        'WHTotal', 'meter3_ac_power', 'meter2_ac_power', 'meter1_ac_power',
#        'metered_ac_power', 'inv_total_ac_power',
#        'String1Current_unshaded', 'String2Current_unshaded',
#        'String11Current_shaded', 'String12Current_shaded',
#        'ac_frequency_1', 'ac_frequency_2', 'ac_frequency_3',
#        'inv3_ac_current', 'inv4_ac_current', 'inv5_ac_current',
#        'inv6_ac_current', 'inv3_ac_voltage', 'inv4_ac_voltage',
#        'inv5_ac_voltage', 'inv6_ac_voltage', 'inv7_ac_current',
#        'inv8_ac_current', 'inv9_ac_current', 'inv2-9_ac_voltage',
#        'inv1_dc_current1', 'inv1_dc_current2', 'inv2_dc_current1',
#        'inv2_dc_current2', 'poa_irradiance_refcell1',
#        'poa_irradiance_refcell2', 'ac_current_phA', 'ac_current_phB',
#        'ac_current_phC', 'power_factor_phA', 'power_factor_phB',
#        'power_factor_phC', 'apparent_power_kVA', 'reactive_power_kVAR',
#        'ac_voltage_LtoL', 'ac_voltage_LtoN', 'ac_voltage_AB',
#        'ac_voltage_BC', 'ac_voltage_AC', 'ac_voltage_AN', 'ac_voltage_BN',
#        'ac_voltage_CN', 'dc_current_positive', 'dc_current_negative',
#        'dc_power_negative', 'dc_power_positive', 'dc_voltage_positive',
#        'dc_voltage_negative', 'enclosure_temp', 'real_power_kW',
#        'real_power_phA_kW', 'real_power_phB_kW', 'real_power_phC_kW',
#        'ac_power_1_KwAC', 'ac_power_2_KwAC', 'ac_power_3_KwAC',
#        'poa_irradiance_Sun', 'module_temp_F_Temp2',
#        'ambient_temp_F_TempF', 'ac_kwhr_1_KwhAC', 'ac_kwhr_2_KwhAC',
#        'ac_kwhr_3_KwhAC', 'wind_speed_mph_WindSpeed',
#        'wind_direction_WindDirection', 'dc_current_1_Idc',
#        'dc_current_2_Idc', 'dc_voltage_1_Vdc', 'dc_voltage_2_Vdc',
#        'ac_power_KwAC', 'dc_current_I2', 'ac_current_Iac',
#        'ac_voltage_Vac', 'module_temp_F_Temp1', 'dc_voltage_Vdc',
#        'ac_kwhr_KwhAC', 'PR', 'kWh_net', 'kWh_gross',
#        'irradiance_global_1', 'irradiance_albedo_2',
#        'irradiance_global_3', 'irradiance_albedo_3',
#        'irradiance_albedo_1', 'irradiance_global_2', 'battery_voltage',
#        'ptemp', 'power_factor_1000', 'poa_irradiance_1',
#        'module8_temp_Top', 'module8_temp_Mid', 'module8_temp_Bot',
#        'inv_temp', 'Module3_Temp', 'Module10NW_Temp', 'Module6NE_Temp',
#        'Module1SW_Temp', 'Module5SE_Temp', 'reflector_temp_1',
#        'module_current_1', 'module_current_2', 'module_current_3',
#        'module_current_4', 'module_current_5', 'module_current_6',
#        'module_current_7', 'module_current_8', 'module_current_9',
#        'module_current_10', 'PhotoDiode_1', 'PhotoDiode_2',
#        'PhotoDiode_3', 'PhotoDiode_4', 'PhotoDiode_5', 'PhotoDiode_6',
#        'AmbTemp_C_Avg', 'Battery_A_Avg', 'Battery_V_Min',
#        'CR1000Temp_C_Avg', 'ChgSource_Min', 'ChgState_Min', 'CkBatt_Max',
#        'InvEtot_kWh_Max', 'InvIa_Avg', 'InvIb_Avg', 'InvIc_Avg',
#        'InvPAC_kW_Avg', 'InvPDC_kW_Avg', 'InvTempFault_Max',
#        'InvVDCin_Avg', 'InvVPVin_Avg', 'InvVa_Avg', 'InvVb_Avg',
#        'InvVc_Avg', 'PwrMtrEdel_kVARh_Max', 'PwrMtrEdel_kWh_Max',
#        'PwrMtrErec_kVARh_Max', 'PwrMtrErec_kWh_Max', 'PwrMtrFreqMax_Max',
#        'PwrMtrFreqMin_Min', 'PwrMtrFreq_Avg', 'PwrMtrPF_Avg',
#        'PwrMtrP_kVAR_Avg', 'PwrMtrP_kVA_Avg', 'PwrMtrP_kW_Avg',
#        'PwrMtrPhaseRev_Avg', 'PwrMtrVaTHDMax_Max', 'PwrMtrVa_Avg',
#        'PwrMtrVbTHDMax_Max', 'PwrMtrVb_Avg', 'PwrMtrVcTHDMax_Max',
#        'PwrMtrVc_Avg', 'Pyra1_mV_Avg', 'Pyra2_mV_Avg', 'Pyra3_mV_Avg',
#        'RTD_C_Avg_1', 'RTD_C_Avg_10', 'RTD_C_Avg_2', 'RTD_C_Avg_3',
#        'RTD_C_Avg_4', 'RTD_C_Avg_5', 'RTD_C_Avg_6', 'RTD_C_Avg_7',
#        'RTD_C_Avg_8', 'RTD_C_Avg_9', 'RefCell1_Wm2_Avg',
#        'RefCell2_Wm2_Avg', 'SEWSAmbientTemp_C_Avg',
#        'SEWSModuleTemp_C_Avg', 'ShuntCurrent_A_Avg_1',
#        'ShuntCurrent_A_Avg_2', 'ShuntCurrent_A_Avg_3',
#        'ShuntCurrent_A_Avg_4', 'ShuntCurrent_A_Avg_5',
#        'ShuntCurrent_A_Avg_6', 'ShuntCurrent_A_Avg_7',
#        'ShuntEtot_kWh_Max_1', 'ShuntEtot_kWh_Max_2',
#        'ShuntEtot_kWh_Max_3', 'ShuntEtot_kWh_Max_4',
#        'ShuntEtot_kWh_Max_5', 'ShuntEtot_kWh_Max_6',
#        'ShuntEtot_kWh_Max_7', 'ShuntPDC_kW_Avg_1', 'ShuntPDC_kW_Avg_2',
#        'ShuntPDC_kW_Avg_3', 'ShuntPDC_kW_Avg_4', 'ShuntPDC_kW_Avg_5',
#        'ShuntPDC_kW_Avg_6', 'ShuntPDC_kW_Avg_7', 'WindHeatStateID_Avg',
#        'WindRef_V_Min', 'WindSpeed_ms_Max', 'WindValid_Avg',
#        'DoorOpen_Min', 'InvDriveFault_Max', 'InvFreq_Avg',
#        'InvGridFault_Max', 'InvIDCin_Avg', 'InvMainFault_Max',
#        'InvOpStatus_Avg', 'InvPVMStatus_Max', 'InvSystemFault_Max',
#        'InvSystemWarn_Max', 'InvVDVoltage_V_Avg', 'InvVoltageFault_Max',
#        'Load_A_Avg', 'PwrMtrIa_Avg', 'PwrMtrIb_Avg', 'PwrMtrIc_Avg',
#        'Qloss_Ah_Max', 'SEWSPOAIrrad_Wm2_Avg', 'WindDirAve_deg',
#        'WindDirStdDev_deg', 'WindSpeedAve_ms', 'InvEtoday_kWh_Max',
#        'InvEyesterday_kWh_Max', 'InvINeutral_Avg', 'InvIUnbal_Avg',
#        'InvIabcAvg_Avg', 'InvPF_Avg', 'InvTempHeatsink_C_Avg',
#        'InvTempInternalAir_C_Avg', 'InvTempInverterAir_C_Avg',
#        'InvVAR_kVAR_Avg', 'InvVA_kVA_Avg', 'InvVUnbal_Avg',
#        'InvVabcAvg_Avg', 'Pyra4_mV_Avg', 'Pyra5_mV_Avg', 'Pyra6_mV_Avg',
#        'Pyra7_mV_Avg', 'Pyra8_mV_Avg', 'RefCell3_Wm2_Avg',
#        'TCTemps_C_Avg_1', 'TCTemps_C_Avg_10', 'TCTemps_C_Avg_11',
#        'TCTemps_C_Avg_12', 'TCTemps_C_Avg_2', 'TCTemps_C_Avg_3',
#        'TCTemps_C_Avg_4', 'TCTemps_C_Avg_5', 'TCTemps_C_Avg_6',
#        'TCTemps_C_Avg_7', 'TCTemps_C_Avg_8', 'TCTemps_C_Avg_9',
#        'TemperatureFaults_Max', 'DPCBFaults_Max', 'GeneralFaults1_Max',
#        'GeneralFaults2_Max', 'HardwareFaults_Max', 'InvGndImped_kOhm_Avg',
#        'InvIGnd_Avg', 'InvOpState_Avg', 'InvVPVIn_Avg',
#        'InverterFaults_Max', 'NumActiveFaults_Max', 'Warnings_Max',
#        'dc_power_1', 'dc_power_2', 'ac_volts', 'dc_neg_current',
#        'inverter_temp_2', 'dc_neg_voltage', 'das_temperature',
#        'inveter_temp'], dtype=object)

# %%
metrics_df['common_name'].unique()
# Out:
# array(['DC power', 'AC power', 'AC current', 'AC voltage', 'DC current',
#        'DC voltage battery', 'Irradiance POA', 'Temperature ambient',
#        'Temperature module', 'Temperature inverter', 'DC voltage',
#        'Temperature panel', 'Temperature other', 'AC other', 'Wind speed',
#        'System status', 'Irradiance GHI', 'Humidity', 'Irradiance DNI',
#        'AC current other', 'AC energy', 'Wind direction',
#        'Temperature refdevice', 'DC current other',
#        'Temperature enclosure', 'AC power other', 'PR', 'AC energy other',
#        'Irradiance albedo', 'Irradiance other', 'DC current battery',
#        'Battery other', 'DC voltage other', 'AC voltage other',
#        'Temperature backsheet', 'DC energy other', 'DC power other',
#        'System other'], dtype=object)

# %%
# collect power_factors
metrics_pf = metrics_df.loc[metrics_df.loc[:, 'sensor_name'].str.contains('factor')]
metrics_pf
# Out:
#       system_id  metric_id        sensor_name common_name raw_units units  \
# 88         1200       4198       power_factor    AC other         -     -
# 94         1201       2799       power_factor    AC other         -     -
# 141        1202       2805       power_factor    AC other         -     -
# 154        1203       2901  inv1_power_factor    AC other         -     -
# 155        1203       2908  inv2_power_factor    AC other         -     -
# 449        1276       3038       power_factor    AC other         -     -
# 464        1277       3053       power_factor    AC other         -     -
# 484        1278       3068  inv1_power_factor    AC other         -     -
# 485        1278       3077  inv2_power_factor    AC other         -     -
# 526        1284        957       power_factor    AC other         -     -
# 556        1289       1074       power_factor    AC other         -     -
# 1112       1416       4746       power_factor    AC other         -     -
# 1113       1416       4753   power_factor_phA    AC other         -     -
# 1114       1416       4754   power_factor_phB    AC other         -     -
# 1115       1416       4755   power_factor_phC    AC other         -     -
# 1318         33        596       power_factor    AC other         -     -
# 1323         34       2693  power_factor_1000    AC other         -     -
# 1338         35       2711  power_factor_1000    AC other         -     -
# 1714          4        327       power_factor    AC other        na    na
#
#       calc_scale  calc_offset calc_details aggregation_type source_type  \
# 88         1.000          0.0                          None        None
# 94         1.000          0.0                           avg        None
# 141        1.000          0.0                          None        None
# 154        1.000          0.0                           avg        None
# 155        1.000          0.0                           avg        None
# 449        1.000          0.0                           avg        None
# 464        1.000          0.0                           avg        None
# 484        1.000          0.0                           avg        None
# 485        1.000          0.0                           avg        None
# 526        1.000          0.0                           avg        None
# 556        1.000          0.0                          None        None
# 1112       1.000          0.0                           avg        None
# 1113       1.000          0.0                           avg        None
# 1114       1.000          0.0                           avg        None
# 1115       1.000          0.0                           avg        None
# 1318       1.000          0.0                          None        None
# 1323       0.001          0.0                           avg        None
# 1338       0.001          0.0                           avg        None
# 1714       1.000          0.0                           avg        None
#
#       source_id comments            standard_name
# 88          NaN                power_factor__4198
# 94          NaN                power_factor__2799
# 141         NaN                power_factor__2805
# 154         NaN           inv1_power_factor__2901
# 155         NaN           inv2_power_factor__2908
# 449         NaN                power_factor__3038
# 464         NaN                power_factor__3053
# 484         NaN           inv1_power_factor__3068
# 485         NaN           inv2_power_factor__3077
# 526         NaN                 power_factor__957
# 556         NaN                power_factor__1074
# 1112        NaN                power_factor__4746
# 1113        NaN            power_factor_pha__4753
# 1114        NaN            power_factor_phb__4754
# 1115        NaN            power_factor_phc__4755
# 1318        NaN                 power_factor__596
# 1323        NaN           power_factor_1000__2693
# 1338        NaN           power_factor_1000__2711
# 1714        NaN                 power_factor__327

# %%
def get_filtered_metrics(system_id: int):
    '''Restrict the metrics to the site in question.'''
    return metrics_df.loc[metrics_df.loc[:,'system_id'] == system_id]

# %%
my_metrics = get_filtered_metrics(1200)
my_metrics
# Out:
#     system_id  metric_id          sensor_name           common_name raw_units  \
# 51       1200       2751             ac_power              AC power         W
# 52       1200       2752             dc_power              DC power         W
# 53       1200       2757        inv1_ac_power              AC power         W
# 54       1200       2758        inv1_dc_power              DC power         W
# 55       1200       2762        inv2_ac_power              AC power         W
# 56       1200       2763        inv2_dc_power              DC power         W
# 57       1200       2767        inv3_ac_power              AC power         W
# 58       1200       2768        inv3_dc_power              DC power         W
# 59       1200       2772        inv4_ac_power              AC power         W
# 60       1200       2773        inv4_dc_power              DC power         W
# 61       1200       2777        inv5_ac_power              AC power         W
# 62       1200       2778        inv5_dc_power              DC power         W
# 63       1200       2782        inv6_ac_power              AC power         W
# 64       1200       2783        inv6_dc_power              DC power         W
# 65       1200       2760      inv1_dc_current            DC current         A
# 66       1200       2765      inv2_dc_current            DC current         A
# 67       1200       2770      inv3_dc_current            DC current         A
# 68       1200       2775      inv4_dc_current            DC current         A
# 69       1200       2780      inv5_dc_current            DC current         A
# 70       1200       2785      inv6_dc_current            DC current         A
# 71       1200       4197  ac_power_metered_kW              AC power        kW
# 72       1200       4199         ac_frequency              AC other        Hz
# 73       1200       2753       poa_irradiance        Irradiance POA     W/m^2
# 74       1200       2755        module_temp_F    Temperature module         C
# 75       1200       2754       ambient_temp_F   Temperature ambient         C
# 76       1200       2761            inv1_temp  Temperature inverter         C
# 77       1200       2766            inv2_temp  Temperature inverter         C
# 78       1200       2771            inv3_temp  Temperature inverter         C
# 79       1200       2776            inv4_temp  Temperature inverter         C
# 80       1200       2781            inv5_temp  Temperature inverter         C
# 81       1200       2786            inv6_temp  Temperature inverter         C
# 82       1200       2759      inv1_dc_voltage            DC voltage         V
# 83       1200       2764      inv2_dc_voltage            DC voltage         V
# 84       1200       2769      inv3_dc_voltage            DC voltage         V
# 85       1200       2774      inv4_dc_voltage            DC voltage         V
# 86       1200       2779      inv5_dc_voltage            DC voltage         V
# 87       1200       2784      inv6_dc_voltage            DC voltage         V
# 88       1200       4198         power_factor              AC other         -
# 89       1200       2756       wind_speed_mph            Wind speed       m/s
#
#     units   calc_scale  calc_offset         calc_details aggregation_type  \
# 51      W     1.000000     0.000000  ac_power_metered_kW              avg
# 52      W     1.000000     0.000000                                   avg
# 53      W     1.000000     0.000000                                   avg
# 54      W     1.000000     0.000000                                   avg
# 55      W     1.000000     0.000000                                   avg
# 56      W     1.000000     0.000000                                   avg
# 57      W     1.000000     0.000000                                   avg
# 58      W     1.000000     0.000000                                   avg
# 59      W     1.000000     0.000000                                   avg
# 60      W     1.000000     0.000000                                   avg
# 61      W     1.000000     0.000000                                   avg
# 62      W     1.000000     0.000000                                   avg
# 63      W     1.000000     0.000000                                   avg
# 64      W     1.000000     0.000000                                   avg
# 65      A     1.000000     0.000000                                   avg
# 66      A     1.000000     0.000000                                   avg
# 67      A     1.000000     0.000000                                   avg
# 68      A     1.000000     0.000000                                   avg
# 69      A     1.000000     0.000000                                   avg
# 70      A     1.000000     0.000000                                   avg
# 71      W  1000.000000     0.000000                                   avg
# 72     Hz     1.000000     0.000000                                   avg
# 73  W/m^2     1.000000     0.000000                                   avg
# 74      C     0.555556   -17.777778                                   avg
# 75      C     0.555556   -17.777778                                   avg
# 76      C     1.000000     0.000000                                   avg
# 77      C     1.000000     0.000000                                   avg
# 78      C     1.000000     0.000000                                   avg
# 79      C     1.000000     0.000000                                   avg
# 80      C     1.000000     0.000000                                   avg
# 81      C     1.000000     0.000000                                   avg
# 82      V     1.000000     0.000000                                   avg
# 83      V     1.000000     0.000000                                   avg
# 84      V     1.000000     0.000000                                   avg
# 85      V     1.000000     0.000000                                   avg
# 86      V     1.000000     0.000000                                   avg
# 87      V     1.000000     0.000000                                   avg
# 88      -     1.000000     0.000000                                  None
# 89    m/s     0.447040     0.000000                                median
#
#    source_type  source_id comments              standard_name
# 51        None        NaN                      ac_power__2751
# 52        None        NaN                      dc_power__2752
# 53        None        NaN                 inv1_ac_power__2757
# 54        None        NaN                 inv1_dc_power__2758
# 55        None        NaN                 inv2_ac_power__2762
# 56        None        NaN                 inv2_dc_power__2763
# 57        None        NaN                 inv3_ac_power__2767
# 58        None        NaN                 inv3_dc_power__2768
# 59        None        NaN                 inv4_ac_power__2772
# 60        None        NaN                 inv4_dc_power__2773
# 61        None        NaN                 inv5_ac_power__2777
# 62        None        NaN                 inv5_dc_power__2778
# 63        None        NaN                 inv6_ac_power__2782
# 64        None        NaN                 inv6_dc_power__2783
# 65        None        NaN               inv1_dc_current__2760
# 66        None        NaN               inv2_dc_current__2765
# 67        None        NaN               inv3_dc_current__2770
# 68        None        NaN               inv4_dc_current__2775
# 69        None        NaN               inv5_dc_current__2780
# 70        None        NaN               inv6_dc_current__2785
# 71        None        NaN           ac_power_metered_kw__4197
# 72        None        NaN                  ac_frequency__4199
# 73        None        NaN                poa_irradiance__2753
# 74        None        NaN                 module_temp_f__2755
# 75        None        NaN                ambient_temp_f__2754
# 76        None        NaN                     inv1_temp__2761
# 77        None        NaN                     inv2_temp__2766
# 78        None        NaN                     inv3_temp__2771
# 79        None        NaN                     inv4_temp__2776
# 80        None        NaN                     inv5_temp__2781
# 81        None        NaN                     inv6_temp__2786
# 82        None        NaN               inv1_dc_voltage__2759
# 83        None        NaN               inv2_dc_voltage__2764
# 84        None        NaN               inv3_dc_voltage__2769
# 85        None        NaN               inv4_dc_voltage__2774
# 86        None        NaN               inv5_dc_voltage__2779
# 87        None        NaN               inv6_dc_voltage__2784
# 88        None        NaN                  power_factor__4198
# 89        None        NaN                wind_speed_mph__2756

# %% [markdown]
# For the current purposes, let's grab DC power, temperature, and irradiance
# *However*, data is stored in the main parquet framework by metric_id,
# so just manually choose the ids you want.

# %%
def get_metric_ids_and_names(system_id: int, selected_metrics,
                             return_type = 'dict_paired'):
    pruned_metrics = metrics_df.loc[
        (metrics_df.loc[:, 'system_id'] == system_id)
        & (metrics_df.loc[:, 'metric_id'].isin(selected_metrics))
    ]
    # basic error_checking
    if pruned_metrics.shape[0] == 0:
        raise ValueError(
            f'Mismatch between system_id {system_id} and metrics '
            + f'{selected_metrics}.\n No values returned!'
        )
    # grab metrics and names in the *same* order
    sorted_metrics = tuple(pruned_metrics['metric_id'])
    sorted_names = tuple(pruned_metrics['common_name'])
    if return_type == 'dict_paired':
        return {
            sorted_metrics[j]: sorted_names[j]
            for j in range(len(sorted_metrics))
        }
    elif return_type == 'dict_separate':
        return {
            'metrics': sorted_metrics,
            'names': sorted_names
        }
    elif return_type == 'tuples':
        return (sorted_metrics, sorted_names)
    else:
        raise ValueError('Not a valid return_type.')

# %% [markdown]
# ## Now read the relevant data
#
# We now read the actual dataset, using our metric_ids to filter.

# %%
def read_and_filter(system_id: int, selected_metrics,
                    name_change='add'):
    '''Grab the data,
    filter for only our metrics,
    name the metrics, 
    and save the data by-metric
    
    Parameters:
    system_id: int
        The system ID number you wish to replace.
    selected_metrics: iterable
        The metrics you want to choose
    name_change: str, any of "add", "drop", or "none"
        If "add", add on common_name to metric_id
        If "replace", replace metric_id with common_name
        If "none", do nothing.
    '''
    access_system_dir = Path(f'../../data/raw/systems/parquet/{system_id}/')
    current_pq = pq.ParquetDataset(
        access_system_dir,
        filters= [('metric_id', 'in', selected_metrics)])
    current_df = current_pq.read().to_pandas()
    # even with raw data, duplicates can happen!
    # only drop *complete* duplicates for now.
    current_df = current_df.drop_duplicates()
    if(name_change == 'add') or (name_change == 'replace'):
        # replace numbers with meaningful names
        correspondence_dict = get_metric_ids_and_names(
            system_id=system_id,
            selected_metrics=selected_metrics,
            return_type='dict_paired'
        )
        current_df['common_name'] = current_df['metric_id'].apply(
            lambda x: correspondence_dict[x]
        )
        # put metric name next to metric id.
        col_reorder = ['measured_on', 'utc_measured_on', 'metric_id', 'common_name', 'value']
        current_df = current_df[col_reorder]
        if name_change == 'replace':
            current_df.drop(
                columns='metric_id'
            )
    return current_df

# %% [markdown]
# Experiments to see what the different options' storage size is.

# %%
power_factor = read_and_filter(1200, [2754], 'add')

# %%
power_factor.loc[25:40, 'value']
# Out:
# 25      56.0108
# 26      55.1223
# 27      54.4838
# 28      53.7838
# 29      53.3707
# 30    3472.5300
# 31    3472.5300
# 32    3472.5300
# 33    3472.5300
# 34    3472.5300
# 35    3472.5300
# 36    3472.5300
# 37      61.3418
# 38      61.3729
# 39      60.2054
# 40      56.9338
# Name: value, dtype: float64

# %%
add_34 = read_and_filter(34,
                         [2694, 2695, 2679, 2686, 2687, 2688, 2689],
                         'add')
add_34.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359161 entries, 0 to 2359160
# Data columns (total 5 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   measured_on      datetime64[ns]
#  1   utc_measured_on  datetime64[ns]
#  2   metric_id        int32
#  3   metric_name      object
#  4   value            float64
# dtypes: datetime64[ns](2), float64(1), int32(1), object(1)
# memory usage: 81.0+ MB

# %%
add_34 = add_34.astype({'metric_name':'str'})

# %%
add_34.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359161 entries, 0 to 2359160
# Data columns (total 5 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   measured_on      datetime64[ns]
#  1   utc_measured_on  datetime64[ns]
#  2   metric_id        int32
#  3   metric_name      object
#  4   value            float64
# dtypes: datetime64[ns](2), float64(1), int32(1), object(1)
# memory usage: 81.0+ MB

# %%
replace_34 = read_and_filter(34,
                         [2694, 2695, 2679, 2686, 2687, 2688, 2689],
                         'replace')
replace_34.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359161 entries, 0 to 2359160
# Data columns (total 5 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   measured_on      datetime64[ns]
#  1   utc_measured_on  datetime64[ns]
#  2   metric_id        int32
#  3   value            float64
#  4   metric_name      object
# dtypes: datetime64[ns](2), float64(1), int32(1), object(1)
# memory usage: 81.0+ MB

# %%
noname_34 = read_and_filter(34,
                         [2694, 2695, 2679, 2686, 2687, 2688, 2689],
                         'none')
noname_34.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359161 entries, 0 to 2359160
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   measured_on      datetime64[ns]
#  1   utc_measured_on  datetime64[ns]
#  2   metric_id        int32
#  3   value            float64
# dtypes: datetime64[ns](2), float64(1), int32(1)
# memory usage: 63.0 MB

# %%
def save_to_parquet(df, system_id, save_dir, pivot_choices):
    save_path = Path(save_dir + f'{system_id}/')
    df.to_parquet(save_path,
                  partition_cols = pivot_choices,
                  index=None)

# %%
save_to_parquet(
    noname_34,
    '34',
    './temp/noname/',
    'metric_id'
)

# %%
save_to_parquet(
    replace_34,
    '34',
    './temp/replace/',
    'common_name'
)

# %%
save_to_parquet(
    add_34,
    '34',
    './temp/addname/',
    'common_name'
)

# %%
save_to_parquet(
    add_34,
    '34',
    './temp/addid/',
    'metric_id'
)

# %% [markdown]
# Result: Significant differences in opened Dataframe size; small differences in stored size.
#
# As per suggestions, keep to 'none' for now.

# %% [markdown]
# ## Let's put it all together

# %%
systems_cleaned = pd.read_csv('../../data/core/systems_cleaned.csv')
parquet_systems = systems_cleaned.loc[
    systems_cleaned.loc[:, 'is_lake_parquet_data']
]  # is already boolean!
irrad_parquet_systems = parquet_systems.loc[
    parquet_systems.loc[:, 'has_irrad_data']
]
my_irrad_parquet_indices = list(
    irrad_parquet_systems.system_id.values
)

# %%
j = 60
system_id = my_irrad_parquet_indices[j]
cur_mets = get_filtered_metrics(system_id=system_id)
cur_mets = cur_mets[['system_id', 'metric_id', 'sensor_name', 'common_name', 'units']]
cur_mets.loc[
    (cur_mets.loc[:, 'sensor_name'].str.contains('Pow'))
    | (cur_mets.loc[:, 'sensor_name'].str.contains('pow'))
    | (cur_mets.loc[:, 'sensor_name'].str.contains('temp'))
    | (cur_mets.loc[:, 'sensor_name'].str.contains('Temp'))
    | (cur_mets.loc[:, 'common_name'].str.contains('ambient'))
    | (cur_mets.loc[:, 'sensor_name'].str.contains('rrad'))
]
# Out:
#       system_id  metric_id               sensor_name            common_name  \
# 1590       4903      82702             AmbTemp_C_Avg    Temperature ambient
# 1593       4903      82689          CR1000Temp_C_Avg  Temperature enclosure
# 1609       4903      82740     InvTempHeatsink_C_Avg   Temperature inverter
# 1610       4903      82738  InvTempInternalAir_C_Avg   Temperature inverter
# 1611       4903      82739  InvTempInverterAir_C_Avg   Temperature inverter
# 1656       4903      82741     SEWSAmbientTemp_C_Avg    Temperature ambient
# 1657       4903      82742      SEWSModuleTemp_C_Avg     Temperature module
# 1670       4903      82798           TCTemps_C_Avg_1      Temperature other
# 1671       4903      82807          TCTemps_C_Avg_10      Temperature other
# 1672       4903      82808          TCTemps_C_Avg_11      Temperature other
# 1673       4903      82809          TCTemps_C_Avg_12      Temperature other
# 1674       4903      82799           TCTemps_C_Avg_2      Temperature other
# 1675       4903      82800           TCTemps_C_Avg_3      Temperature other
# 1676       4903      82801           TCTemps_C_Avg_4      Temperature other
# 1677       4903      82802           TCTemps_C_Avg_5      Temperature other
# 1678       4903      82803           TCTemps_C_Avg_6      Temperature other
# 1679       4903      82804           TCTemps_C_Avg_7      Temperature other
# 1680       4903      82805           TCTemps_C_Avg_8      Temperature other
# 1681       4903      82806           TCTemps_C_Avg_9      Temperature other
# 1682       4903      82709     TemperatureFaults_Max      Temperature other
# 1706       4903      82743      SEWSPOAIrrad_Wm2_Avg           System other
#
#       units
# 1590      C
# 1593      C
# 1609      C
# 1610      C
# 1611      C
# 1656      C
# 1657      C
# 1670      C
# 1671      C
# 1672      C
# 1673      C
# 1674      C
# 1675      C
# 1676      C
# 1677      C
# 1678      C
# 1679      C
# 1680      C
# 1681      C
# 1682      -
# 1706  W/m^2

# %%
my_metrics = []
where_to_store = '../../data/sorted_by_metric/systems/parquet/'

# %%
current_df = read_and_filter(system_id=system_id, selected_metrics=my_metrics, name_change='none')
save_to_parquet(current_df, system_id, where_to_store, ['metric_id'])

# %%
no_power_sites = [1294, 1295, 1296, 1297, 1298, 1299, 1301,
                  1302, 1303, 1304, 1309, 1311, 4901, 4902, 4903]
